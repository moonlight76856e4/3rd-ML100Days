# %%
import os
import tensorflow.keras as keras

os.environ["CUDA_VISIBLE_DEVICES"] = ""

# %%
train, test = keras.datasets.cifar10.load_data()

# %%
def preproc_x(x, flatten=True):
    x = x / 255.
    if flatten:
        x = x.reshape((len(x), -1))
    return x

def preproc_y(y, num_classes=10):
    if y.shape[-1] == 1:
        y = keras.utils.to_categorical(y, num_classes)
    return y

# %%
x_train, y_train = train
x_test, y_test = test

# Preproc the inputs
x_train = preproc_x(x_train)
x_test = preproc_x(x_test)

# Preprc the outputs
y_train = preproc_y(y_train)
y_test = preproc_y(y_test)

# %%
from tensorflow.keras.layers import BatchNormalization

def build_mlp(input_shape, output_units=10, num_neurons=[256, 256, 256]):
    input_layer = keras.layers.Input(input_shape)
    
    for i, n_units in enumerate(num_neurons):
        if i == 0:
            x = keras.layers.Dense(units=n_units, 
                                   activation="relu", 
                                   name="hidden_layer"+str(i+1))(input_layer)
            x = BatchNormalization()(x)
        else:
            x = keras.layers.Dense(units=n_units, 
                                   activation="relu", 
                                   name="hidden_layer"+str(i+1))(x)
            x = BatchNormalization()(x)
    
    out = keras.layers.Dense(units=output_units, activation="softmax", name="output")(x)
    
    model = keras.models.Model(inputs=[input_layer], outputs=[out])
    return model

# %%
LEARNING_RATE = 1e-3
EPOCHS = 25
BATCH_SIZE = 1024
MOMENTUM = 0.95

# %%
from tensorflow.keras.callbacks import Callback

# Record_fp_tp
class Record_tp_tn(Callback):
    def on_train_begin(self, epoch, logs = {}):
        self.validation_data = (x_test, y_test)
        logs = logs or {}
        record_items = ["val_tp", "val_tn"]
        for i in record_items:
            if i not in self.params['metrics']:
                self.params['metrics'].append(i)
    
    def on_epoch_end(self, epoch, logs = {}, thres=0.5):
        logs = logs or {}
        y_true = self.validation_data[1].argmax(axis = 1)
        y_pred = self.model.predict(self.validation_data[0])
        y_pred = (y_pred[:, 1] >= thres) * 1
        
        logs["val_tp"] = sum((y_true==1) & (y_pred==1))
        logs["val_tn"] = sum((y_true==0) & (y_pred==0))
        
rec_tptn = Record_tp_tn()

# %%
model = build_mlp(input_shape=x_train.shape[1:])
model.summary()
optimizer = keras.optimizers.SGD(lr=LEARNING_RATE, nesterov=True, momentum=MOMENTUM)
model.compile(loss="categorical_crossentropy", metrics=["accuracy"], optimizer=optimizer)

model.fit(x_train, y_train, 
          epochs=EPOCHS, 
          batch_size=BATCH_SIZE, 
          validation_data=(x_test, y_test), 
          shuffle=True,
          callbacks=[rec_tptn]
         )

# Collect results
train_loss = model.history.history["loss"]
valid_loss = model.history.history["val_loss"]
train_acc = model.history.history["accuracy"]
valid_acc = model.history.history["val_accuracy"]

valid_tp = model.history.history['val_tp']
valid_tn = model.history.history['val_tn']
# Out:
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 3072)]            0
# _________________________________________________________________
# hidden_layer1 (Dense)        (None, 256)               786688
# _________________________________________________________________
# batch_normalization (BatchNo (None, 256)               1024
# _________________________________________________________________
# hidden_layer2 (Dense)        (None, 256)               65792
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 256)               1024
# _________________________________________________________________
# hidden_layer3 (Dense)        (None, 256)               65792
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 256)               1024
# _________________________________________________________________
# output (Dense)               (None, 10)                2570
# =================================================================
# Total params: 923,914
# Trainable params: 922,378
# Non-trainable params: 1,536
# _________________________________________________________________
# Train on 50000 samples, validate on 10000 samples
# Epoch 1/25
# 50000/50000 [==============================] - 6s 123us/sample - loss: 2.2464 - accuracy: 0.2609 - val_loss: 2.1679 - val_accuracy: 0.1852 - val_tp: 0.0000e+00 - val_tn: 1000.0000
# Epoch 2/25
# 50000/50000 [==============================] - 2s 31us/sample - loss: 1.7761 - accuracy: 0.3811 - val_loss: 2.0158 - val_accuracy: 0.2484 - val_tp: 0.0000e+00 - val_tn: 1000.0000
# Epoch 3/25
# 50000/50000 [==============================] - 2s 35us/sample - loss: 1.6441 - accuracy: 0.4261 - val_loss: 1.8690 - val_accuracy: 0.3336 - val_tp: 1.0000 - val_tn: 1000.0000
# Epoch 4/25
# 50000/50000 [==============================] - 2s 39us/sample - loss: 1.5656 - accuracy: 0.4521 - val_loss: 1.7312 - val_accuracy: 0.3919 - val_tp: 15.0000 - val_tn: 1000.0000
# Epoch 5/25
# 50000/50000 [==============================] - 2s 37us/sample - loss: 1.5108 - accuracy: 0.4715 - val_loss: 1.6387 - val_accuracy: 0.4231 - val_tp: 65.0000 - val_tn: 1000.0000
# Epoch 6/25
# 50000/50000 [==============================] - 2s 35us/sample - loss: 1.4655 - accuracy: 0.4897 - val_loss: 1.5859 - val_accuracy: 0.4377 - val_tp: 143.0000 - val_tn: 1000.0000
# Epoch 7/25
# 50000/50000 [==============================] - 2s 35us/sample - loss: 1.4281 - accuracy: 0.5019 - val_loss: 1.5543 - val_accuracy: 0.4438 - val_tp: 226.0000 - val_tn: 996.0000
# Epoch 8/25
# 50000/50000 [==============================] - 2s 32us/sample - loss: 1.3943 - accuracy: 0.5150 - val_loss: 1.5253 - val_accuracy: 0.4563 - val_tp: 281.0000 - val_tn: 993.0000
# Epoch 9/25
# 50000/50000 [==============================] - 2s 31us/sample - loss: 1.3639 - accuracy: 0.5254 - val_loss: 1.5014 - val_accuracy: 0.4654 - val_tp: 274.0000 - val_tn: 991.0000
# Epoch 10/25
# 50000/50000 [==============================] - 2s 32us/sample - loss: 1.3352 - accuracy: 0.5362 - val_loss: 1.4930 - val_accuracy: 0.4681 - val_tp: 436.0000 - val_tn: 982.0000
# Epoch 11/25
# 50000/50000 [==============================] - 2s 35us/sample - loss: 1.3086 - accuracy: 0.5443 - val_loss: 1.4830 - val_accuracy: 0.4729 - val_tp: 379.0000 - val_tn: 988.0000
# Epoch 12/25
# 50000/50000 [==============================] - 2s 34us/sample - loss: 1.2842 - accuracy: 0.5541 - val_loss: 1.4817 - val_accuracy: 0.4714 - val_tp: 407.0000 - val_tn: 986.0000
# Epoch 13/25
# 50000/50000 [==============================] - 2s 31us/sample - loss: 1.2614 - accuracy: 0.5610 - val_loss: 1.4651 - val_accuracy: 0.4773 - val_tp: 403.0000 - val_tn: 986.0000
# Epoch 14/25
# 50000/50000 [==============================] - 2s 31us/sample - loss: 1.2399 - accuracy: 0.5702 - val_loss: 1.4654 - val_accuracy: 0.4791 - val_tp: 416.0000 - val_tn: 988.0000
# Epoch 15/25
# 50000/50000 [==============================] - 2s 33us/sample - loss: 1.2195 - accuracy: 0.5776 - val_loss: 1.4627 - val_accuracy: 0.4826 - val_tp: 488.0000 - val_tn: 976.0000
# Epoch 16/25
# 50000/50000 [==============================] - 2s 34us/sample - loss: 1.1988 - accuracy: 0.5837 - val_loss: 1.4443 - val_accuracy: 0.4894 - val_tp: 471.0000 - val_tn: 977.0000
# Epoch 17/25
# 50000/50000 [==============================] - 2s 38us/sample - loss: 1.1789 - accuracy: 0.5917 - val_loss: 1.4591 - val_accuracy: 0.4817 - val_tp: 521.0000 - val_tn: 972.0000
# Epoch 18/25
# 50000/50000 [==============================] - 2s 42us/sample - loss: 1.1602 - accuracy: 0.5980 - val_loss: 1.4480 - val_accuracy: 0.4873 - val_tp: 415.0000 - val_tn: 989.0000
# Epoch 19/25
# 50000/50000 [==============================] - 2s 41us/sample - loss: 1.1432 - accuracy: 0.6050 - val_loss: 1.4358 - val_accuracy: 0.4922 - val_tp: 412.0000 - val_tn: 988.0000
# Epoch 20/25
# 50000/50000 [==============================] - 2s 38us/sample - loss: 1.1258 - accuracy: 0.6117 - val_loss: 1.4332 - val_accuracy: 0.4903 - val_tp: 421.0000 - val_tn: 984.0000
# Epoch 21/25
# 50000/50000 [==============================] - 2s 37us/sample - loss: 1.1066 - accuracy: 0.6202 - val_loss: 1.4398 - val_accuracy: 0.4947 - val_tp: 496.0000 - val_tn: 977.0000
# Epoch 22/25
# 50000/50000 [==============================] - 2s 35us/sample - loss: 1.0895 - accuracy: 0.6247 - val_loss: 1.4434 - val_accuracy: 0.4902 - val_tp: 427.0000 - val_tn: 982.0000
# Epoch 23/25
# 50000/50000 [==============================] - 2s 34us/sample - loss: 1.0737 - accuracy: 0.6318 - val_loss: 1.4364 - val_accuracy: 0.4907 - val_tp: 490.0000 - val_tn: 976.0000
# Epoch 24/25
# 50000/50000 [==============================] - 2s 37us/sample - loss: 1.0552 - accuracy: 0.6385 - val_loss: 1.4410 - val_accuracy: 0.4889 - val_tp: 496.0000 - val_tn: 974.0000
# Epoch 25/25
# 50000/50000 [==============================] - 2s 37us/sample - loss: 1.0399 - accuracy: 0.6440 - val_loss: 1.4368 - val_accuracy: 0.4937 - val_tp: 463.0000 - val_tn: 984.0000

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

plt.plot(range(len(train_loss)), train_loss, label="train loss")
plt.plot(range(len(valid_loss)), valid_loss, label="valid loss")
plt.legend()
plt.title("Loss")
plt.show()

plt.plot(range(len(train_acc)), train_acc, label="train accuracy")
plt.plot(range(len(valid_acc)), valid_acc, label="valid accuracy")
plt.legend()
plt.title("Accuracy")
plt.show()

plt.plot(range(len(valid_tp)), valid_tp, label="valid tp", color="navy")
plt.plot(range(len(valid_tn)), valid_tn, label="valid tn", color="red")
plt.legend()
plt.title("True positives and True Negatives")
plt.show()
